# %%
# Potrzebne biblioteki
import pandas as pd
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, mean_squared_error
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import GradientBoostingClassifier
from os import rename
import re

# %%
# !pip install catboost
# Out:
# Requirement already satisfied: catboost in /usr/local/lib/python3.10/dist-packages (1.2.7)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.10.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.26.4)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.13.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.2.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (9.0.0)

# %%
# Dodanie naszej zescrapowanej bazy danych z dodaną kolumną określającą gatunek
dane_pieski_i_kotki = pd.read_csv("dane_cale.csv")

dane_pieski_i_kotki.index = dane_pieski_i_kotki.index + 1
df_dane_pieski_i_kotki = pd.DataFrame(dane_pieski_i_kotki)

df_dane_pieski_i_kotki
# Out:
#             name                                               opis  \
# 1     Brak nazwy  Tak wygląda złamane psie serce...przed Wami Ra...
# 2     Brak nazwy                                                NaN
# 3     Brak nazwy  Rita jest z nami od niedawna. Pierwsze dni w s...
# 4     Brak nazwy  Raja trafiła do nas skrajnie wychudzony i zani...
# 5     Brak nazwy                                                NaN
# ...          ...                                                ...
# 5996  Brak nazwy  Romcio to młody 8-miesięczny, wesoły burasek. ...
# 5997  Brak nazwy  Tego kota możecie poznać w punkcie Ochota na K...
# 5998  Brak nazwy                                                NaN
# 5999  Brak nazwy  Arya to średniej wielkości, energiczna i łagod...
# 6000  Brak nazwy  Homer to energiczny młody pies, który straszni...
#
#                     rasa        wiek    płeć   waga    numer          status  \
# 1             Mieszaniec      10 lat  samiec  19 kg  1213/24  wydane adopcja
# 2              Bernardyn  6 miesięcy  samiec  38 kg  1706/24   wydane odbiór
# 3     Owczarek niemiecki       5 lat  samica  30 kg  1123/24  wydane adopcja
# 4             Mieszaniec      14 lat  samica  17 kg  1389/24  wydane adopcja
# 5             Mieszaniec  9 miesięcy  samiec  11 kg  1683/24   wydane odbiór
# ...                  ...         ...     ...    ...      ...             ...
# 5996          Europejska      2 lata  samiec   2 kg  1206/22  wydane adopcja
# 5997          Europejska       5 lat  samica   3 kg  1234/22  wydane adopcja
# 5998          Europejska      2 lata  samica   1 kg  1289/22  wydane adopcja
# 5999          Mieszaniec      3 lata  samica  17 kg  1075/22  wydane adopcja
# 6000          Mieszaniec      4 lata  samiec  26 kg  1357/22  wydane adopcja
#
#         przyjęty      wydany  \
# 1     2024-08-23  2024-12-11
# 2     2024-12-10  2024-12-11
# 3     2024-08-01  2024-12-11
# 4     2024-10-03  2024-12-10
# 5     2024-12-06  2024-12-10
# ...          ...         ...
# 5996  2022-11-03  2022-11-27
# 5997  2022-11-08  2022-11-27
# 5998  2022-11-22  2022-11-27
# 5999  2022-06-28  2022-11-26
# 6000  2022-08-17  2022-11-26
#
#                                              znaleziony         zdjecie  \
# 1                                                   NaN     image_1.jpg
# 2     Warszawa, skrzyżowanie Al. Krakowskiej/ Na Skraju     image_2.jpg
# 3                                 Warszawa, ul Ogrodowa     image_3.jpg
# 4                                 Warszawa, ul. Srebrna     image_4.jpg
# 5                                 Warszawa, ul. Korkowa     image_5.jpg
# ...                                                 ...             ...
# 5996                         aleja Komandosów, Warszawa  image_6056.jpg
# 5997                           Warszawa, ul. Bakalarska  image_6057.jpg
# 5998                         Porzucony pod schroniskiem  image_6058.jpg
# 5999                                Warszawa, ul Płocka  image_6059.jpg
# 6000                             ul. Sielska, Siedliska  image_6060.jpg
#
#      gatunek
# 1       pies
# 2       pies
# 3       pies
# 4       pies
# 5       pies
# ...      ...
# 5996     kot
# 5997    pies
# 5998    pies
# 5999    pies
# 6000    pies
#
# [6000 rows x 13 columns]

# %%
# Dla większej dokładności przypisania gatunku zmieniamy gatunek w zależności od znalezienia określonych zwrotów w opisie zwierzęcia
lista_psia = [r"pies", r"psi", r"psiu", r"szczeni", "psy", r"suni"]
lista_kocia = [r"kot", r"koci", r"kici"]

lista_wykluczajace_kot = ["nie lubi kotów"]
lista_wykluczajace_pies = [r"piesz"]

def contains_whole_word(text, word_list, exclude_list=[]):
    # Sprawdzanie wykluczających fraz
    if any(re.search(rf"\b{word}(?=\s|$)", text) for word in exclude_list):
        return False
    # Dopasowanie całych słów
    return any(re.search(rf"\b{word}(?=\s|$)", text) for word in word_list)

# Aktualizacja kolumny "gatunek" dla psów
df_dane_pieski_i_kotki["gatunek"] = df_dane_pieski_i_kotki.apply(
    lambda row: "pies" if pd.notna(row["opis"]) and contains_whole_word(str(row["opis"]), lista_psia, lista_wykluczajace_pies) else row["gatunek"],
    axis=1
)

# Aktualizacja kolumny "gatunek" dla kotów
df_dane_pieski_i_kotki["gatunek"] = df_dane_pieski_i_kotki.apply(
    lambda row: "kot" if pd.notna(row["opis"]) and contains_whole_word(str(row["opis"]), lista_kocia, lista_wykluczajace_kot) else row["gatunek"],
    axis=1
)

# %%
# Zmiana na małe litery
df_dane_pieski_i_kotki["rasa"] = df_dane_pieski_i_kotki["rasa"].str.lower()

# %%
# Dla większej dokładności przypisania gatunku zmieniamy gatunek na podstawie ras występujących w bazie danych
# Dla kotów, ponieważ większość zwierząt została rozpoznana jako psy
rasy_kotow = [
    "syberyjski", "mix ragdoll", "ragdoll", "chausie", "syryjski",
    "norweski leśny", "selkirk rf", "syjamski", "europejska", "devon rex",
    "rosyjski niebieski", "święty kot birmański", "sfinks",
    "szkocki zwisłouchy", "bengalski", "abisyński", "perski"
]

df_dane_pieski_i_kotki["gatunek"] = df_dane_pieski_i_kotki.apply(
    lambda row: "kot" if row["rasa"] in rasy_kotow else row["gatunek"],
    axis=1
)

# %%
# Usunięcie występujących pojedynczo innych gatunków zwierząt z bazy danych
lista_do_wyrzucenia =  [
    "królik", "mysz domowa", "królik miniaturowy",
    "mix jagdtf", "fuzzy", "skinny", "rozetka",
    "dżungarski", "peruwianka",
    "mix ast", "myszoskoczek",
    "ratatuj", "mix buld", "szynszyla",
]

df_dane_pieski_i_kotki = df_dane_pieski_i_kotki[~df_dane_pieski_i_kotki["rasa"].isin(lista_do_wyrzucenia)].reset_index(drop = True)

# %%
df_dane_pieski_i_kotki["gatunek"].value_counts()
# Out:
# gatunek
# pies    3696
# kot     2226
# Name: count, dtype: int64

# %%
# Usunięcie zbędnych kolumn z bazy danych
do_wyrzucenia = ["name", "numer", "status", "znaleziony"]
dane = df_dane_pieski_i_kotki.drop(columns = do_wyrzucenia)

# %%
# Wyciągnięcie liczby i jednostki z kolumny wiek i utworzenie nowych kolumn z tymi wartościami
dane[['wiek_liczba', 'wiek_jednostka']] = dane['wiek'].str.extract(r'(\d+)\s*(\w+)')
dane['wiek_liczba'] = dane['wiek_liczba'].astype(int)

# Analogicznie dla wagi
dane[['waga_kg', 'waga_jednostka']] = dane['waga'].str.extract(r'(\d+)\s*(\w+)')
dane['waga_kg'] = dane['waga_kg'].astype(int)

# %%
# Ujednolicenie jednostki i dodanie nowej kolumny z tą wartością
def przelicz_wiek(row):
    if row["wiek_jednostka"] in ["rok", "lat", "lata"]:
        return row["wiek_liczba"] * 12
    return row["wiek_liczba"]

dane["wiek_liczba_prawidłowa"] = dane.apply(przelicz_wiek, axis = 1)

# %%
# Usunięcie zbędnych kolumn
do_wyrzucenia = ["wiek", "wiek_liczba", "wiek_jednostka"]
dane = dane.drop(columns = do_wyrzucenia)

# %%
# Obliczenie czasu pobytu zwierzęcia w schronisku w dniach i dodanie nowej kolumny z tą wartością
dane["przyjęty"] = pd.to_datetime(dane["przyjęty"])
dane["wydany"] = pd.to_datetime(dane["wydany"])

dane["czas_pobytu"] = (dane["wydany"] - dane["przyjęty"]).dt.days

# %%
# Usunięcie zbędnych kolumn
do_wyrzucenia = ["waga", "przyjęty", "wydany", "waga_jednostka", "zdjecie"]
dane = dane.drop(columns = do_wyrzucenia)

# %%
# Zmiana nazw kolumn
dane = dane.rename(columns={"wiek_liczba_prawidłowa": "wiek_miesiące", "czas_pobytu": "czas_pobytu_dni"})

# %%
# Pustym wartościom przypisujemy wybrane wartości dla wygody
dane["opis"] = dane["opis"].fillna("Brak opisu").astype(str)

dane["czas_pobytu_dni"] = dane["czas_pobytu_dni"].fillna(0).astype(int)

# Zmiana liter w rasach na małe
dane["rasa"] = dane["rasa"].str.lower()

# %%
# Definicja słów kluczowych dla kategorii
# Kategorie opisują cechy zwierząt
kategorie = {
    "przyjazny": [r"przyjazn", r"łagodn", "kocha ludzi", "uwielbia zabawę", r"przytul", r"merda", r"szczęśliw", r"liz", "wita", r"grzeczn", r"delikatn"],
    "agresywny": [r"agresyw", r"dominując", "wymaga doświadczonego opiekuna", r"niebezpieczn", r"gryz", r"atak"],
    "chory": [r"chor", r"choroba", "wymaga leczenia", "opieka weterynaryjna", r"lek", "choruje na", r"niepełnosprawn", r"ślep", r"zmęczon", r"cierp"],
    "bojący się": ["boi się", r"wycofan", r"strachliw", r"nieśmiał", "na dystans", "chowa się", "trzęsie się", "piszczy", "kuli ogon"],
    "aktywny": [r"aktywn", "biega", "sportowiec", "pełen energii", r"energi", "zabawa", r"bawi"]
}

# Funkcja przypisująca kategorię na podstawie opisu
def przypisz_kategorie(opis):
    kategorie_zwierze = []
    for kategoria, slowa_kluczowe in kategorie.items():
        if any(slowo in opis.lower() for slowo in slowa_kluczowe):  # Dopasowanie słów kluczowych
            kategorie_zwierze.append(kategoria)
    return ", ".join(kategorie_zwierze) if kategorie_zwierze else "niezidentyfikowany"

# Tworzenie nowej kolumny z kategoriami
dane["kategoria"] = dane["opis"].apply(przypisz_kategorie)

dane["kategoria"].value_counts()
# Out:
# kategoria
# niezidentyfikowany                                  2786
# przyjazny                                            778
# przyjazny, aktywny                                   505
# aktywny                                              364
# przyjazny, chory                                     257
# przyjazny, chory, aktywny                            224
# chory                                                172
# przyjazny, bojący się                                152
# chory, aktywny                                       108
# przyjazny, bojący się, aktywny                       100
# bojący się                                            77
# przyjazny, chory, bojący się                          74
# przyjazny, chory, bojący się, aktywny                 64
# chory, bojący się                                     40
# bojący się, aktywny                                   37
# przyjazny, agresywny, aktywny                         23
# agresywny, aktywny                                    20
# przyjazny, agresywny, chory, aktywny                  18
# agresywny                                             18
# przyjazny, agresywny, chory                           17
# przyjazny, agresywny                                  16
# chory, bojący się, aktywny                            16
# agresywny, chory, aktywny                             14
# przyjazny, agresywny, chory, bojący się, aktywny       9
# agresywny, chory                                       7
# przyjazny, agresywny, bojący się, aktywny              7
# przyjazny, agresywny, chory, bojący się                5
# przyjazny, agresywny, bojący się                       4
# agresywny, chory, bojący się                           4
# agresywny, bojący się                                  3
# agresywny, chory, bojący się, aktywny                  2
# agresywny, bojący się, aktywny                         1
# Name: count, dtype: int64

# %%
# Iteracja po nazwach kategorii i dodanie nowych kolumn
for kategoria in kategorie.keys():
    dane[kategoria] = dane["kategoria"].apply(lambda x: 1 if kategoria in x else 0)

# %%
dane["płeć"].value_counts()
# Out:
# płeć
# samiec    3249
# samica    2672
# nn           1
# Name: count, dtype: int64

# %%
# Usuń wiersze, gdzie wartość w kolumnie 'płeć' wynosi 'nn'
dane = dane[dane["płeć"] != "nn"]

# %%
#dane.to_csv('czyste_dane.csv', index = False)

# %%
dane
# Out:
#                                                    opis                rasa  \
# 0     Tak wygląda złamane psie serce...przed Wami Ra...          mieszaniec
# 1                                            Brak opisu           bernardyn
# 2     Rita jest z nami od niedawna. Pierwsze dni w s...  owczarek niemiecki
# 3     Raja trafiła do nas skrajnie wychudzony i zani...          mieszaniec
# 4                                            Brak opisu          mieszaniec
# ...                                                 ...                 ...
# 5917  Romcio to młody 8-miesięczny, wesoły burasek. ...          europejska
# 5918  Tego kota możecie poznać w punkcie Ochota na K...          europejska
# 5919                                         Brak opisu          europejska
# 5920  Arya to średniej wielkości, energiczna i łagod...          mieszaniec
# 5921  Homer to energiczny młody pies, który straszni...          mieszaniec
#
#         płeć gatunek  waga_kg  wiek_miesiące  czas_pobytu_dni  \
# 0     samiec    pies       19            120              110
# 1     samiec    pies       38              6                1
# 2     samica    pies       30             60              132
# 3     samica    pies       17            168               68
# 4     samiec    pies       11              9                4
# ...      ...     ...      ...            ...              ...
# 5917  samiec     kot        2             24               24
# 5918  samica     kot        3             60               19
# 5919  samica     kot        1             24                5
# 5920  samica    pies       17             36              151
# 5921  samiec    pies       26             48              101
#
#                                   kategoria  przyjazny  agresywny  chory  \
# 0                          agresywny, chory          0          1      1
# 1                        niezidentyfikowany          0          0      0
# 2     przyjazny, chory, bojący się, aktywny          1          0      1
# 3                                 przyjazny          1          0      0
# 4                        niezidentyfikowany          0          0      0
# ...                                     ...        ...        ...    ...
# 5917                         chory, aktywny          0          0      1
# 5918                              przyjazny          1          0      0
# 5919                     niezidentyfikowany          0          0      0
# 5920                     przyjazny, aktywny          1          0      0
# 5921                         chory, aktywny          0          0      1
#
#       bojący się  aktywny
# 0              0        0
# 1              0        0
# 2              1        1
# 3              0        0
# 4              0        0
# ...          ...      ...
# 5917           0        1
# 5918           0        0
# 5919           0        0
# 5920           0        1
# 5921           0        1
#
# [5921 rows x 13 columns]

# %%
# Usunięcie zbędnych kolumn
df_do_modelu = dane.drop(columns=["kategoria", "opis"])

# %%
# Utworzenie osobnych kolumn dla każdej z kategorii, dla działania modelu i przypisanie wierszom
# odpowiednio 0 i 1 gdy dana kategoria nie występuje lub występuje
df_do_modelu["przyjazny"] = df_do_modelu["przyjazny"].astype("category")
df_do_modelu["agresywny"] = df_do_modelu["agresywny"].astype("category")
df_do_modelu["chory"] = df_do_modelu["chory"].astype("category")
df_do_modelu["bojący się"] = df_do_modelu["bojący się"].astype("category")
df_do_modelu["aktywny"] = df_do_modelu["aktywny"].astype("category")

# %%
# Podobnie dla rasy, płci i gatunku, ale tutaj wartościami będzie False i True
df_do_modelu = pd.get_dummies(df_do_modelu, columns = ["rasa", "płeć", "gatunek"], drop_first = False)

# %%
# Przesunięcie kolumny z czasem pobytu na sam koniec
kolumny = [kol for kol in df_do_modelu.columns if kol != "czas_pobytu_dni"]
kolumny.append("czas_pobytu_dni")

df_do_modelu = df_do_modelu[kolumny]

# %%
# Pobranie danych gotowych do użycia modelu w streamlit
df_do_modelu.to_csv('dane.csv', index=False, header=True)
df_do_modelu
# Out:
#       waga_kg  wiek_miesiące przyjazny agresywny chory bojący się aktywny  \
# 0          19            120         0         1     1          0       0
# 1          38              6         0         0     0          0       0
# 2          30             60         1         0     1          1       1
# 3          17            168         1         0     0          0       0
# 4          11              9         0         0     0          0       0
# ...       ...            ...       ...       ...   ...        ...     ...
# 5917        2             24         0         0     1          0       1
# 5918        3             60         1         0     0          0       0
# 5919        1             24         0         0     0          0       0
# 5920       17             36         1         0     0          0       1
# 5921       26             48         0         0     1          0       1
#
#       rasa_abisyński  rasa_akita inu  rasa_amstaff  ...  rasa_wyżeł fran  \
# 0              False           False         False  ...            False
# 1              False           False         False  ...            False
# 2              False           False         False  ...            False
# 3              False           False         False  ...            False
# 4              False           False         False  ...            False
# ...              ...             ...           ...  ...              ...
# 5917           False           False         False  ...            False
# 5918           False           False         False  ...            False
# 5919           False           False         False  ...            False
# 5920           False           False         False  ...            False
# 5921           False           False         False  ...            False
#
#       rasa_wyżeł weimarski  rasa_yorkshire terier  rasa_łajka  \
# 0                    False                  False       False
# 1                    False                  False       False
# 2                    False                  False       False
# 3                    False                  False       False
# 4                    False                  False       False
# ...                    ...                    ...         ...
# 5917                 False                  False       False
# 5918                 False                  False       False
# 5919                 False                  False       False
# 5920                 False                  False       False
# 5921                 False                  False       False
#
#       rasa_święty kot birmański  płeć_samica  płeć_samiec  gatunek_kot  \
# 0                         False        False         True        False
# 1                         False        False         True        False
# 2                         False         True        False        False
# 3                         False         True        False        False
# 4                         False        False         True        False
# ...                         ...          ...          ...          ...
# 5917                      False        False         True         True
# 5918                      False         True        False         True
# 5919                      False         True        False         True
# 5920                      False         True        False        False
# 5921                      False        False         True        False
#
#       gatunek_pies  czas_pobytu_dni
# 0             True              110
# 1             True                1
# 2             True              132
# 3             True               68
# 4             True                4
# ...            ...              ...
# 5917         False               24
# 5918         False               19
# 5919         False                5
# 5920          True              151
# 5921          True              101
#
# [5921 rows x 128 columns]

# %%
# Podział bazy danych na zbiór uczący i testowy
(train_set, test_set) = train_test_split(df_do_modelu, train_size = 0.7, random_state = 13)

print('Train size:', train_set.shape[0])
print('Test size:', test_set.shape[0])
# Out:
# Train size: 4144
# Test size: 1777

# %%
# Liczba kolumn
liczba_kolumn = len(df_do_modelu.columns)

# %%
# Podział kolumn na zmienne objaśniające i zmienną objaśnianą (w naszym przypadku czas pobytu zwierzęcia w schronisku)
train_inputs = train_set.iloc[:, 0:(liczba_kolumn - 1)]
train_days = train_set.iloc[:, (liczba_kolumn - 1)]
test_inputs = test_set.iloc[:, 0:(liczba_kolumn - 1)]
test_days = test_set.iloc[:, (liczba_kolumn - 1)]

# %% [markdown]
# ## SZUKANIE NAJLEPSZEGO MODELU

# %% [markdown]
# # RANDOM FOREST

# %%
# Stworzenie wielu kombinacji do wybrania najlepszych parametrów
model = RandomForestRegressor(random_state = 13)

param_grid = {
    'max_depth': [5, 10, 15, 20, None],  # Możliwe wartości max_depth
    'n_estimators': [50, 100, 200, 300],  # Liczba drzew w lesie
    'random_state': [13, 42, 123]  # Testowanie kilku różnych random_state
}

grid_search = GridSearchCV(estimator = model, param_grid=param_grid, cv = 5, scoring = 'r2', verbose = 2)

# Dopasowanie modelu do danych
grid_search.fit(train_inputs, train_days)

# Wyświetlenie najlepszych parametrów i wyniku
print("Najlepsze parametry:", grid_search.best_params_)
print("Najlepsze R²:", grid_search.best_score_)
# Out:
# Fitting 5 folds for each of 60 candidates, totalling 300 fits
# [CV] END ......max_depth=5, n_estimators=50, random_state=13; total time=   0.4s
# [CV] END ......max_depth=5, n_estimators=50, random_state=13; total time=   0.3s
# [CV] END ......max_depth=5, n_estimators=50, random_state=13; total time=   0.4s
# [CV] END ......max_depth=5, n_estimators=50, random_state=13; total time=   0.4s
# [CV] END ......max_depth=5, n_estimators=50, random_state=13; total time=   0.4s
# [CV] END ......max_depth=5, n_estimators=50, random_state=42; total time=   0.4s
# [CV] END ......max_depth=5, n_estimators=50, random_state=42; total time=   0.5s
# [CV] END ......max_depth=5, n_estimators=50, random_state=42; total time=   0.6s
# [CV] END ......max_depth=5, n_estimators=50, random_state=42; total time=   0.4s
# [CV] END ......max_depth=5, n_estimators=50, random_state=42; total time=   0.4s
# [CV] END .....max_depth=5, n_estimators=50, random_state=123; total time=   0.5s
# [CV] END .....max_depth=5, n_estimators=50, random_state=123; total time=   1.0s
# [CV] END .....max_depth=5, n_estimators=50, random_state=123; total time=   0.6s
# [CV] END .....max_depth=5, n_estimators=50, random_state=123; total time=   0.8s
# [CV] END .....max_depth=5, n_estimators=50, random_state=123; total time=   0.5s
# [CV] END .....max_depth=5, n_estimators=100, random_state=13; total time=   1.0s
# [CV] END .....max_depth=5, n_estimators=100, random_state=13; total time=   0.8s
# [CV] END .....max_depth=5, n_estimators=100, random_state=13; total time=   0.8s
# [CV] END .....max_depth=5, n_estimators=100, random_state=13; total time=   0.9s
# [CV] END .....max_depth=5, n_estimators=100, random_state=13; total time=   0.8s
# [CV] END .....max_depth=5, n_estimators=100, random_state=42; total time=   0.7s
# [CV] END .....max_depth=5, n_estimators=100, random_state=42; total time=   0.7s
# [CV] END .....max_depth=5, n_estimators=100, random_state=42; total time=   0.7s
# [CV] END .....max_depth=5, n_estimators=100, random_state=42; total time=   0.8s
# [CV] END .....max_depth=5, n_estimators=100, random_state=42; total time=   0.4s
# [CV] END ....max_depth=5, n_estimators=100, random_state=123; total time=   0.4s
# [CV] END ....max_depth=5, n_estimators=100, random_state=123; total time=   0.4s
# [CV] END ....max_depth=5, n_estimators=100, random_state=123; total time=   0.4s
# [CV] END ....max_depth=5, n_estimators=100, random_state=123; total time=   0.4s
# [CV] END ....max_depth=5, n_estimators=100, random_state=123; total time=   0.6s
# [CV] END .....max_depth=5, n_estimators=200, random_state=13; total time=   1.2s
# [CV] END .....max_depth=5, n_estimators=200, random_state=13; total time=   0.9s
# [CV] END .....max_depth=5, n_estimators=200, random_state=13; total time=   0.8s
# [CV] END .....max_depth=5, n_estimators=200, random_state=13; total time=   0.8s
# [CV] END .....max_depth=5, n_estimators=200, random_state=13; total time=   0.8s
# [CV] END .....max_depth=5, n_estimators=200, random_state=42; total time=   0.8s
# [CV] END .....max_depth=5, n_estimators=200, random_state=42; total time=   0.8s
# [CV] END .....max_depth=5, n_estimators=200, random_state=42; total time=   0.8s
# [CV] END .....max_depth=5, n_estimators=200, random_state=42; total time=   0.8s
# [CV] END .....max_depth=5, n_estimators=200, random_state=42; total time=   0.8s
# [CV] END ....max_depth=5, n_estimators=200, random_state=123; total time=   0.8s
# [CV] END ....max_depth=5, n_estimators=200, random_state=123; total time=   0.8s
# [CV] END ....max_depth=5, n_estimators=200, random_state=123; total time=   0.8s
# [CV] END ....max_depth=5, n_estimators=200, random_state=123; total time=   0.8s
# [CV] END ....max_depth=5, n_estimators=200, random_state=123; total time=   1.1s
# [CV] END .....max_depth=5, n_estimators=300, random_state=13; total time=   1.5s
# [CV] END .....max_depth=5, n_estimators=300, random_state=13; total time=   1.1s
# [CV] END .....max_depth=5, n_estimators=300, random_state=13; total time=   1.1s
# [CV] END .....max_depth=5, n_estimators=300, random_state=13; total time=   1.1s
# [CV] END .....max_depth=5, n_estimators=300, random_state=13; total time=   1.1s
# [CV] END .....max_depth=5, n_estimators=300, random_state=42; total time=   1.1s
# [CV] END .....max_depth=5, n_estimators=300, random_state=42; total time=   1.1s
# [CV] END .....max_depth=5, n_estimators=300, random_state=42; total time=   1.1s
# [CV] END .....max_depth=5, n_estimators=300, random_state=42; total time=   1.1s
# [CV] END .....max_depth=5, n_estimators=300, random_state=42; total time=   1.6s
# [CV] END ....max_depth=5, n_estimators=300, random_state=123; total time=   1.4s
# [CV] END ....max_depth=5, n_estimators=300, random_state=123; total time=   1.1s
# [CV] END ....max_depth=5, n_estimators=300, random_state=123; total time=   1.1s
# [CV] END ....max_depth=5, n_estimators=300, random_state=123; total time=   1.1s
# [CV] END ....max_depth=5, n_estimators=300, random_state=123; total time=   1.1s
# [CV] END .....max_depth=10, n_estimators=50, random_state=13; total time=   0.3s
# [CV] END .....max_depth=10, n_estimators=50, random_state=13; total time=   0.3s
# [CV] END .....max_depth=10, n_estimators=50, random_state=13; total time=   0.3s
# [CV] END .....max_depth=10, n_estimators=50, random_state=13; total time=   0.3s
# [CV] END .....max_depth=10, n_estimators=50, random_state=13; total time=   0.3s
# [CV] END .....max_depth=10, n_estimators=50, random_state=42; total time=   0.3s
# [CV] END .....max_depth=10, n_estimators=50, random_state=42; total time=   0.3s
# [CV] END .....max_depth=10, n_estimators=50, random_state=42; total time=   0.3s
# [CV] END .....max_depth=10, n_estimators=50, random_state=42; total time=   0.3s
# [CV] END .....max_depth=10, n_estimators=50, random_state=42; total time=   0.3s
# [CV] END ....max_depth=10, n_estimators=50, random_state=123; total time=   0.3s
# [CV] END ....max_depth=10, n_estimators=50, random_state=123; total time=   0.3s
# [CV] END ....max_depth=10, n_estimators=50, random_state=123; total time=   0.3s
# [CV] END ....max_depth=10, n_estimators=50, random_state=123; total time=   0.3s
# [CV] END ....max_depth=10, n_estimators=50, random_state=123; total time=   0.3s
# [CV] END ....max_depth=10, n_estimators=100, random_state=13; total time=   1.0s
# [CV] END ....max_depth=10, n_estimators=100, random_state=13; total time=   1.0s
# [CV] END ....max_depth=10, n_estimators=100, random_state=13; total time=   0.8s
# [CV] END ....max_depth=10, n_estimators=100, random_state=13; total time=   0.7s
# [CV] END ....max_depth=10, n_estimators=100, random_state=13; total time=   0.8s
# [CV] END ....max_depth=10, n_estimators=100, random_state=42; total time=   0.8s
# [CV] END ....max_depth=10, n_estimators=100, random_state=42; total time=   0.6s
# [CV] END ....max_depth=10, n_estimators=100, random_state=42; total time=   0.6s
# [CV] END ....max_depth=10, n_estimators=100, random_state=42; total time=   0.6s
# [CV] END ....max_depth=10, n_estimators=100, random_state=42; total time=   0.6s
# [CV] END ...max_depth=10, n_estimators=100, random_state=123; total time=   0.6s
# [CV] END ...max_depth=10, n_estimators=100, random_state=123; total time=   0.6s
# [CV] END ...max_depth=10, n_estimators=100, random_state=123; total time=   0.6s
# [CV] END ...max_depth=10, n_estimators=100, random_state=123; total time=   0.6s
# [CV] END ...max_depth=10, n_estimators=100, random_state=123; total time=   0.6s
# [CV] END ....max_depth=10, n_estimators=200, random_state=13; total time=   1.2s
# [CV] END ....max_depth=10, n_estimators=200, random_state=13; total time=   1.8s
# [CV] END ....max_depth=10, n_estimators=200, random_state=13; total time=   1.4s
# [CV] END ....max_depth=10, n_estimators=200, random_state=13; total time=   1.2s
# [CV] END ....max_depth=10, n_estimators=200, random_state=13; total time=   1.2s
# [CV] END ....max_depth=10, n_estimators=200, random_state=42; total time=   1.2s
# [CV] END ....max_depth=10, n_estimators=200, random_state=42; total time=   1.2s
# [CV] END ....max_depth=10, n_estimators=200, random_state=42; total time=   1.3s
# [CV] END ....max_depth=10, n_estimators=200, random_state=42; total time=   1.2s
# [CV] END ....max_depth=10, n_estimators=200, random_state=42; total time=   1.2s
# [CV] END ...max_depth=10, n_estimators=200, random_state=123; total time=   1.6s
# [CV] END ...max_depth=10, n_estimators=200, random_state=123; total time=   1.6s
# [CV] END ...max_depth=10, n_estimators=200, random_state=123; total time=   1.2s
# [CV] END ...max_depth=10, n_estimators=200, random_state=123; total time=   1.2s
# [CV] END ...max_depth=10, n_estimators=200, random_state=123; total time=   1.2s
# [CV] END ....max_depth=10, n_estimators=300, random_state=13; total time=   1.8s
# [CV] END ....max_depth=10, n_estimators=300, random_state=13; total time=   1.8s
# [CV] END ....max_depth=10, n_estimators=300, random_state=13; total time=   1.8s
# [CV] END ....max_depth=10, n_estimators=300, random_state=13; total time=   2.5s
# [CV] END ....max_depth=10, n_estimators=300, random_state=13; total time=   1.8s
# [CV] END ....max_depth=10, n_estimators=300, random_state=42; total time=   1.8s
# [CV] END ....max_depth=10, n_estimators=300, random_state=42; total time=   1.8s
# [CV] END ....max_depth=10, n_estimators=300, random_state=42; total time=   1.8s
# [CV] END ....max_depth=10, n_estimators=300, random_state=42; total time=   1.8s
# [CV] END ....max_depth=10, n_estimators=300, random_state=42; total time=   2.4s
# [CV] END ...max_depth=10, n_estimators=300, random_state=123; total time=   1.9s
# [CV] END ...max_depth=10, n_estimators=300, random_state=123; total time=   1.8s
# [CV] END ...max_depth=10, n_estimators=300, random_state=123; total time=   1.8s
# [CV] END ...max_depth=10, n_estimators=300, random_state=123; total time=   1.8s
# [CV] END ...max_depth=10, n_estimators=300, random_state=123; total time=   1.8s
# [CV] END .....max_depth=15, n_estimators=50, random_state=13; total time=   0.4s
# [CV] END .....max_depth=15, n_estimators=50, random_state=13; total time=   0.4s
# [CV] END .....max_depth=15, n_estimators=50, random_state=13; total time=   0.4s
# [CV] END .....max_depth=15, n_estimators=50, random_state=13; total time=   0.6s
# [CV] END .....max_depth=15, n_estimators=50, random_state=13; total time=   0.6s
# [CV] END .....max_depth=15, n_estimators=50, random_state=42; total time=   0.7s
# [CV] END .....max_depth=15, n_estimators=50, random_state=42; total time=   0.4s
# [CV] END .....max_depth=15, n_estimators=50, random_state=42; total time=   0.4s
# [CV] END .....max_depth=15, n_estimators=50, random_state=42; total time=   0.4s
# [CV] END .....max_depth=15, n_estimators=50, random_state=42; total time=   0.4s
# [CV] END ....max_depth=15, n_estimators=50, random_state=123; total time=   0.4s
# [CV] END ....max_depth=15, n_estimators=50, random_state=123; total time=   0.4s
# [CV] END ....max_depth=15, n_estimators=50, random_state=123; total time=   0.4s
# [CV] END ....max_depth=15, n_estimators=50, random_state=123; total time=   0.4s
# [CV] END ....max_depth=15, n_estimators=50, random_state=123; total time=   0.4s
# [CV] END ....max_depth=15, n_estimators=100, random_state=13; total time=   0.8s
# [CV] END ....max_depth=15, n_estimators=100, random_state=13; total time=   0.8s
# [CV] END ....max_depth=15, n_estimators=100, random_state=13; total time=   0.8s
# [CV] END ....max_depth=15, n_estimators=100, random_state=13; total time=   0.8s
# [CV] END ....max_depth=15, n_estimators=100, random_state=13; total time=   0.8s
# [CV] END ....max_depth=15, n_estimators=100, random_state=42; total time=   0.8s
# [CV] END ....max_depth=15, n_estimators=100, random_state=42; total time=   0.8s
# [CV] END ....max_depth=15, n_estimators=100, random_state=42; total time=   0.8s
# [CV] END ....max_depth=15, n_estimators=100, random_state=42; total time=   1.0s
# [CV] END ....max_depth=15, n_estimators=100, random_state=42; total time=   1.2s
# [CV] END ...max_depth=15, n_estimators=100, random_state=123; total time=   0.8s
# [CV] END ...max_depth=15, n_estimators=100, random_state=123; total time=   0.8s
# [CV] END ...max_depth=15, n_estimators=100, random_state=123; total time=   0.8s
# [CV] END ...max_depth=15, n_estimators=100, random_state=123; total time=   0.8s
# [CV] END ...max_depth=15, n_estimators=100, random_state=123; total time=   0.8s
# [CV] END ....max_depth=15, n_estimators=200, random_state=13; total time=   1.5s
# [CV] END ....max_depth=15, n_estimators=200, random_state=13; total time=   1.6s
# [CV] END ....max_depth=15, n_estimators=200, random_state=13; total time=   1.6s
# [CV] END ....max_depth=15, n_estimators=200, random_state=13; total time=   1.5s
# [CV] END ....max_depth=15, n_estimators=200, random_state=13; total time=   2.3s
# [CV] END ....max_depth=15, n_estimators=200, random_state=42; total time=   1.6s
# [CV] END ....max_depth=15, n_estimators=200, random_state=42; total time=   1.5s
# [CV] END ....max_depth=15, n_estimators=200, random_state=42; total time=   1.6s
# [CV] END ....max_depth=15, n_estimators=200, random_state=42; total time=   1.5s
# [CV] END ....max_depth=15, n_estimators=200, random_state=42; total time=   1.5s
# [CV] END ...max_depth=15, n_estimators=200, random_state=123; total time=   1.5s
# [CV] END ...max_depth=15, n_estimators=200, random_state=123; total time=   2.2s
# [CV] END ...max_depth=15, n_estimators=200, random_state=123; total time=   1.7s
# [CV] END ...max_depth=15, n_estimators=200, random_state=123; total time=   1.5s
# [CV] END ...max_depth=15, n_estimators=200, random_state=123; total time=   1.5s
# [CV] END ....max_depth=15, n_estimators=300, random_state=13; total time=   2.3s
# [CV] END ....max_depth=15, n_estimators=300, random_state=13; total time=   2.3s
# [CV] END ....max_depth=15, n_estimators=300, random_state=13; total time=   3.0s
# [CV] END ....max_depth=15, n_estimators=300, random_state=13; total time=   2.3s
# [CV] END ....max_depth=15, n_estimators=300, random_state=13; total time=   2.3s
# [CV] END ....max_depth=15, n_estimators=300, random_state=42; total time=   2.3s
# [CV] END ....max_depth=15, n_estimators=300, random_state=42; total time=   2.3s
# [CV] END ....max_depth=15, n_estimators=300, random_state=42; total time=   3.1s
# [CV] END ....max_depth=15, n_estimators=300, random_state=42; total time=   2.3s
# [CV] END ....max_depth=15, n_estimators=300, random_state=42; total time=   2.3s
# [CV] END ...max_depth=15, n_estimators=300, random_state=123; total time=   2.3s
# [CV] END ...max_depth=15, n_estimators=300, random_state=123; total time=   2.3s
# [CV] END ...max_depth=15, n_estimators=300, random_state=123; total time=   3.1s
# [CV] END ...max_depth=15, n_estimators=300, random_state=123; total time=   2.3s
# [CV] END ...max_depth=15, n_estimators=300, random_state=123; total time=   2.3s
# [CV] END .....max_depth=20, n_estimators=50, random_state=13; total time=   0.4s
# [CV] END .....max_depth=20, n_estimators=50, random_state=13; total time=   0.4s
# [CV] END .....max_depth=20, n_estimators=50, random_state=13; total time=   0.4s
# [CV] END .....max_depth=20, n_estimators=50, random_state=13; total time=   0.4s
# [CV] END .....max_depth=20, n_estimators=50, random_state=13; total time=   0.4s
# [CV] END .....max_depth=20, n_estimators=50, random_state=42; total time=   0.4s
# [CV] END .....max_depth=20, n_estimators=50, random_state=42; total time=   0.4s
# [CV] END .....max_depth=20, n_estimators=50, random_state=42; total time=   0.4s
# [CV] END .....max_depth=20, n_estimators=50, random_state=42; total time=   0.4s
# [CV] END .....max_depth=20, n_estimators=50, random_state=42; total time=   0.4s
# [CV] END ....max_depth=20, n_estimators=50, random_state=123; total time=   0.6s
# [CV] END ....max_depth=20, n_estimators=50, random_state=123; total time=   0.7s
# [CV] END ....max_depth=20, n_estimators=50, random_state=123; total time=   0.7s
# [CV] END ....max_depth=20, n_estimators=50, random_state=123; total time=   0.5s
# [CV] END ....max_depth=20, n_estimators=50, random_state=123; total time=   0.4s
# [CV] END ....max_depth=20, n_estimators=100, random_state=13; total time=   0.9s
# [CV] END ....max_depth=20, n_estimators=100, random_state=13; total time=   0.9s
# [CV] END ....max_depth=20, n_estimators=100, random_state=13; total time=   0.8s
# [CV] END ....max_depth=20, n_estimators=100, random_state=13; total time=   0.8s
# [CV] END ....max_depth=20, n_estimators=100, random_state=13; total time=   0.9s
# [CV] END ....max_depth=20, n_estimators=100, random_state=42; total time=   0.8s
# [CV] END ....max_depth=20, n_estimators=100, random_state=42; total time=   0.8s
# [CV] END ....max_depth=20, n_estimators=100, random_state=42; total time=   0.9s
# [CV] END ....max_depth=20, n_estimators=100, random_state=42; total time=   0.8s
# [CV] END ....max_depth=20, n_estimators=100, random_state=42; total time=   0.8s
# [CV] END ...max_depth=20, n_estimators=100, random_state=123; total time=   0.9s
# [CV] END ...max_depth=20, n_estimators=100, random_state=123; total time=   1.4s
# [CV] END ...max_depth=20, n_estimators=100, random_state=123; total time=   1.1s
# [CV] END ...max_depth=20, n_estimators=100, random_state=123; total time=   0.8s
# [CV] END ...max_depth=20, n_estimators=100, random_state=123; total time=   0.8s
# [CV] END ....max_depth=20, n_estimators=200, random_state=13; total time=   1.7s
# [CV] END ....max_depth=20, n_estimators=200, random_state=13; total time=   1.6s
# [CV] END ....max_depth=20, n_estimators=200, random_state=13; total time=   1.7s
# [CV] END ....max_depth=20, n_estimators=200, random_state=13; total time=   1.6s
# [CV] END ....max_depth=20, n_estimators=200, random_state=13; total time=   1.9s
# [CV] END ....max_depth=20, n_estimators=200, random_state=42; total time=   2.1s
# [CV] END ....max_depth=20, n_estimators=200, random_state=42; total time=   1.7s
# [CV] END ....max_depth=20, n_estimators=200, random_state=42; total time=   1.7s
# [CV] END ....max_depth=20, n_estimators=200, random_state=42; total time=   1.6s
# [CV] END ....max_depth=20, n_estimators=200, random_state=42; total time=   1.6s
# [CV] END ...max_depth=20, n_estimators=200, random_state=123; total time=   1.7s
# [CV] END ...max_depth=20, n_estimators=200, random_state=123; total time=   2.1s
# [CV] END ...max_depth=20, n_estimators=200, random_state=123; total time=   2.0s
# [CV] END ...max_depth=20, n_estimators=200, random_state=123; total time=   1.6s
# [CV] END ...max_depth=20, n_estimators=200, random_state=123; total time=   1.7s
# [CV] END ....max_depth=20, n_estimators=300, random_state=13; total time=   2.5s
# [CV] END ....max_depth=20, n_estimators=300, random_state=13; total time=   2.5s
# [CV] END ....max_depth=20, n_estimators=300, random_state=13; total time=   3.2s
# [CV] END ....max_depth=20, n_estimators=300, random_state=13; total time=   2.4s
# [CV] END ....max_depth=20, n_estimators=300, random_state=13; total time=   2.5s
# [CV] END ....max_depth=20, n_estimators=300, random_state=42; total time=   2.5s
# [CV] END ....max_depth=20, n_estimators=300, random_state=42; total time=   3.1s
# [CV] END ....max_depth=20, n_estimators=300, random_state=42; total time=   2.7s
# [CV] END ....max_depth=20, n_estimators=300, random_state=42; total time=   2.4s
# [CV] END ....max_depth=20, n_estimators=300, random_state=42; total time=   2.5s
# [CV] END ...max_depth=20, n_estimators=300, random_state=123; total time=   2.5s
# [CV] END ...max_depth=20, n_estimators=300, random_state=123; total time=   3.3s
# [CV] END ...max_depth=20, n_estimators=300, random_state=123; total time=   2.6s
# [CV] END ...max_depth=20, n_estimators=300, random_state=123; total time=   2.5s
# [CV] END ...max_depth=20, n_estimators=300, random_state=123; total time=   2.5s
# [CV] END ...max_depth=None, n_estimators=50, random_state=13; total time=   0.4s
# [CV] END ...max_depth=None, n_estimators=50, random_state=13; total time=   0.4s
# [CV] END ...max_depth=None, n_estimators=50, random_state=13; total time=   0.6s
# [CV] END ...max_depth=None, n_estimators=50, random_state=13; total time=   0.7s
# [CV] END ...max_depth=None, n_estimators=50, random_state=13; total time=   0.7s
# [CV] END ...max_depth=None, n_estimators=50, random_state=42; total time=   0.6s
# [CV] END ...max_depth=None, n_estimators=50, random_state=42; total time=   0.5s
# [CV] END ...max_depth=None, n_estimators=50, random_state=42; total time=   0.5s
# [CV] END ...max_depth=None, n_estimators=50, random_state=42; total time=   0.4s
# [CV] END ...max_depth=None, n_estimators=50, random_state=42; total time=   0.5s
# [CV] END ..max_depth=None, n_estimators=50, random_state=123; total time=   0.4s
# [CV] END ..max_depth=None, n_estimators=50, random_state=123; total time=   0.4s
# [CV] END ..max_depth=None, n_estimators=50, random_state=123; total time=   0.5s
# [CV] END ..max_depth=None, n_estimators=50, random_state=123; total time=   0.4s
# [CV] END ..max_depth=None, n_estimators=50, random_state=123; total time=   0.4s
# [CV] END ..max_depth=None, n_estimators=100, random_state=13; total time=   0.9s
# [CV] END ..max_depth=None, n_estimators=100, random_state=13; total time=   0.9s
# [CV] END ..max_depth=None, n_estimators=100, random_state=13; total time=   0.9s
# [CV] END ..max_depth=None, n_estimators=100, random_state=13; total time=   0.8s
# [CV] END ..max_depth=None, n_estimators=100, random_state=13; total time=   0.9s
# [CV] END ..max_depth=None, n_estimators=100, random_state=42; total time=   0.9s
# [CV] END ..max_depth=None, n_estimators=100, random_state=42; total time=   1.1s
# [CV] END ..max_depth=None, n_estimators=100, random_state=42; total time=   2.2s
# [CV] END ..max_depth=None, n_estimators=100, random_state=42; total time=   1.0s
# [CV] END ..max_depth=None, n_estimators=100, random_state=42; total time=   1.1s
# [CV] END .max_depth=None, n_estimators=100, random_state=123; total time=   1.3s
# [CV] END .max_depth=None, n_estimators=100, random_state=123; total time=   0.9s
# [CV] END .max_depth=None, n_estimators=100, random_state=123; total time=   0.9s
# [CV] END .max_depth=None, n_estimators=100, random_state=123; total time=   0.9s
# [CV] END .max_depth=None, n_estimators=100, random_state=123; total time=   0.9s
# [CV] END ..max_depth=None, n_estimators=200, random_state=13; total time=   1.7s
# [CV] END ..max_depth=None, n_estimators=200, random_state=13; total time=   2.2s
# [CV] END ..max_depth=None, n_estimators=200, random_state=13; total time=   2.1s
# [CV] END ..max_depth=None, n_estimators=200, random_state=13; total time=   1.7s
# [CV] END ..max_depth=None, n_estimators=200, random_state=13; total time=   1.7s
# [CV] END ..max_depth=None, n_estimators=200, random_state=42; total time=   1.8s
# [CV] END ..max_depth=None, n_estimators=200, random_state=42; total time=   1.7s
# [CV] END ..max_depth=None, n_estimators=200, random_state=42; total time=   1.8s
# [CV] END ..max_depth=None, n_estimators=200, random_state=42; total time=   2.4s
# [CV] END ..max_depth=None, n_estimators=200, random_state=42; total time=   1.7s
# [CV] END .max_depth=None, n_estimators=200, random_state=123; total time=   1.8s
# [CV] END .max_depth=None, n_estimators=200, random_state=123; total time=   1.7s
# [CV] END .max_depth=None, n_estimators=200, random_state=123; total time=   1.8s
# [CV] END .max_depth=None, n_estimators=200, random_state=123; total time=   1.7s
# [CV] END .max_depth=None, n_estimators=200, random_state=123; total time=   2.2s
# [CV] END ..max_depth=None, n_estimators=300, random_state=13; total time=   2.9s
# [CV] END ..max_depth=None, n_estimators=300, random_state=13; total time=   2.6s
# [CV] END ..max_depth=None, n_estimators=300, random_state=13; total time=   2.7s
# [CV] END ..max_depth=None, n_estimators=300, random_state=13; total time=   2.5s
# [CV] END ..max_depth=None, n_estimators=300, random_state=13; total time=   3.2s
# [CV] END ..max_depth=None, n_estimators=300, random_state=42; total time=   2.7s
# [CV] END ..max_depth=None, n_estimators=300, random_state=42; total time=   2.6s
# [CV] END ..max_depth=None, n_estimators=300, random_state=42; total time=   2.7s
# [CV] END ..max_depth=None, n_estimators=300, random_state=42; total time=   3.2s
# [CV] END ..max_depth=None, n_estimators=300, random_state=42; total time=   2.5s
# [CV] END .max_depth=None, n_estimators=300, random_state=123; total time=   2.6s
# [CV] END .max_depth=None, n_estimators=300, random_state=123; total time=   2.6s
# [CV] END .max_depth=None, n_estimators=300, random_state=123; total time=   3.4s
# [CV] END .max_depth=None, n_estimators=300, random_state=123; total time=   2.5s
# [CV] END .max_depth=None, n_estimators=300, random_state=123; total time=   2.6s
# Najlepsze parametry: {'max_depth': 5, 'n_estimators': 50, 'random_state': 123}
# Najlepsze R²: 0.2500398937813612

# %%
# Model z najlepszymi parametrami
model1 = RandomForestRegressor(max_depth = 5, random_state = 13, n_estimators = 50)

model1.fit(train_inputs, train_days)
# Out:
# RandomForestRegressor(max_depth=5, n_estimators=50, random_state=13)

# %%
# Dopasowanie modelu
model1.score(test_inputs, test_days)
# Out:
# 0.34053263189367045

# %%
# Sprawdzenie dopasowania na wykresie
import matplotlib.pyplot as plt

preds = model1.predict(test_inputs)
plt.scatter(test_days, preds)
plt.xlabel("Rzeczywiste wartości")
plt.ylabel("Przewidywane wartości")
plt.title("Porównanie rzeczywistych i przewidywanych wartości")
plt.show()

# %% [markdown]
# # CATBOOST

# %%
from catboost import CatBoostRegressor

cat_features = ["przyjazny", "agresywny", "chory", "bojący się", "aktywny"]

# Tworzenie modelu CatBoost
catboost_model = CatBoostRegressor(
    iterations=500,
    learning_rate=0.1,
    depth=6,
    random_seed=42,
    verbose=100
)

# Dopasowanie modelu z uwzględnieniem cech kategorycznych
catboost_model.fit(
    train_inputs, train_days,
    cat_features=cat_features
)

# Wynik na zbiorze testowym
print("CatBoost R² na zbiorze testowym:", catboost_model.score(test_inputs, test_days))
# Out:
# 0:	learn: 195.9984497	total: 47.1ms	remaining: 23.5s
# 100:	learn: 151.9812910	total: 126ms	remaining: 499ms
# 200:	learn: 136.9845210	total: 208ms	remaining: 309ms
# 300:	learn: 130.8257459	total: 294ms	remaining: 195ms
# 400:	learn: 125.6098408	total: 375ms	remaining: 92.7ms
# 499:	learn: 121.4850848	total: 464ms	remaining: 0us
# CatBoost R² na zbiorze testowym: 0.30933513979817595

# %% [markdown]
# # SIECI NEURONOWE

# %%
import numpy as np
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from sklearn.metrics import r2_score

# Konwersja danych na float32
train_inputs = train_inputs.astype(np.float32)
test_inputs = test_inputs.astype(np.float32)
train_days = train_days.astype(np.float32)
test_days = test_days.astype(np.float32)

# Tworzenie modelu sieci neuronowej
model_nn = Sequential([
    Dense(128, activation='relu', input_dim=train_inputs.shape[1]),
    Dense(64, activation='relu'),
    Dense(1, activation='linear')  # Wyjście regresyjne
])

# Kompilacja modelu
model_nn.compile(optimizer='adam', loss='mean_squared_error', metrics=['mae'])

# Trenowanie modelu
model_nn.fit(train_inputs, train_days, epochs=50, batch_size=32, validation_split=0.2, verbose=1)

# Ocena modelu
nn_preds = model_nn.predict(test_inputs)

r2_score(test_days, nn_preds)
# Out:
# /usr/local/lib/python3.10/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 35784.1562 - mae: 82.4223 - val_loss: 39466.9062 - val_mae: 97.5138
# Epoch 2/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 67063.8438 - mae: 95.7841 - val_loss: 37532.5156 - val_mae: 91.2984
# Epoch 3/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 31727.4551 - mae: 80.7797 - val_loss: 36057.8945 - val_mae: 96.2135
# Epoch 4/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 46161.8594 - mae: 86.8115 - val_loss: 35092.5508 - val_mae: 93.9113
# Epoch 5/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 35661.6914 - mae: 82.8280 - val_loss: 33826.5781 - val_mae: 88.9087
# Epoch 6/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 27286.4883 - mae: 81.2895 - val_loss: 32827.3906 - val_mae: 85.0476
# Epoch 7/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 42370.1562 - mae: 80.6743 - val_loss: 31996.7285 - val_mae: 89.6767
# Epoch 8/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 23755.0098 - mae: 78.8767 - val_loss: 31523.2695 - val_mae: 83.2335
# Epoch 9/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 30401.8652 - mae: 75.5825 - val_loss: 30964.4004 - val_mae: 83.1199
# Epoch 10/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 28989.8711 - mae: 78.6427 - val_loss: 31140.7500 - val_mae: 79.1281
# Epoch 11/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 43471.9180 - mae: 79.5638 - val_loss: 30545.7207 - val_mae: 81.0641
# Epoch 12/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 26129.2031 - mae: 72.0750 - val_loss: 30080.7109 - val_mae: 84.0359
# Epoch 13/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 43981.7148 - mae: 77.1288 - val_loss: 29878.5352 - val_mae: 84.7246
# Epoch 14/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 27397.2109 - mae: 74.7451 - val_loss: 30149.6758 - val_mae: 80.6653
# Epoch 15/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 41930.9883 - mae: 79.9689 - val_loss: 29948.5059 - val_mae: 78.8670
# Epoch 16/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 28977.9590 - mae: 75.8829 - val_loss: 29671.8535 - val_mae: 85.4893
# Epoch 17/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 29638.6348 - mae: 78.6486 - val_loss: 30701.9727 - val_mae: 75.7274
# Epoch 18/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 26461.1406 - mae: 69.6287 - val_loss: 29606.2676 - val_mae: 82.5216
# Epoch 19/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 25944.8730 - mae: 71.9987 - val_loss: 29752.9746 - val_mae: 78.2971
# Epoch 20/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 30143.5527 - mae: 72.4950 - val_loss: 29266.1621 - val_mae: 80.3592
# Epoch 21/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 30545.0605 - mae: 77.3929 - val_loss: 29961.2910 - val_mae: 74.9361
# Epoch 22/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 30222.7402 - mae: 75.0870 - val_loss: 29347.6816 - val_mae: 78.9837
# Epoch 23/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 27460.4824 - mae: 73.9074 - val_loss: 29088.9395 - val_mae: 78.1600
# Epoch 24/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 39699.8125 - mae: 75.7221 - val_loss: 29251.6797 - val_mae: 77.2720
# Epoch 25/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 26873.6973 - mae: 70.2914 - val_loss: 29440.3359 - val_mae: 86.7215
# Epoch 26/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 41263.3867 - mae: 77.3446 - val_loss: 29178.7793 - val_mae: 75.6465
# Epoch 27/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 23697.8105 - mae: 70.4985 - val_loss: 29208.8594 - val_mae: 83.4900
# Epoch 28/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 26022.4004 - mae: 72.9090 - val_loss: 28953.0840 - val_mae: 76.0404
# Epoch 29/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 48965.1055 - mae: 82.4631 - val_loss: 30102.1055 - val_mae: 71.4109
# Epoch 30/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 48316.6953 - mae: 68.6764 - val_loss: 29083.1914 - val_mae: 75.4670
# Epoch 31/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 33604.5039 - mae: 70.7188 - val_loss: 28907.4941 - val_mae: 78.3915
# Epoch 32/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 23692.4609 - mae: 69.1485 - val_loss: 28906.9883 - val_mae: 76.7577
# Epoch 33/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 25740.0195 - mae: 67.4021 - val_loss: 28746.9551 - val_mae: 77.1173
# Epoch 34/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 50833.4688 - mae: 78.9616 - val_loss: 29068.5566 - val_mae: 84.8787
# Epoch 35/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 25039.8672 - mae: 71.4997 - val_loss: 29739.8359 - val_mae: 90.3185
# Epoch 36/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 25716.6348 - mae: 70.1152 - val_loss: 28845.2832 - val_mae: 76.7447
# Epoch 37/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 23027.4355 - mae: 66.5284 - val_loss: 29193.0703 - val_mae: 75.3972
# Epoch 38/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 26155.0625 - mae: 72.9587 - val_loss: 28677.6426 - val_mae: 77.9613
# Epoch 39/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 36555.5312 - mae: 71.7043 - val_loss: 28882.1133 - val_mae: 81.9539
# Epoch 40/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 23351.4062 - mae: 70.0793 - val_loss: 28937.8750 - val_mae: 81.8330
# Epoch 41/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 40413.3906 - mae: 71.5189 - val_loss: 29110.5723 - val_mae: 73.3670
# Epoch 42/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 29080.2129 - mae: 69.7239 - val_loss: 29478.4707 - val_mae: 72.3182
# Epoch 43/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 33552.7148 - mae: 70.0302 - val_loss: 28990.3613 - val_mae: 80.7935
# Epoch 44/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 21784.7188 - mae: 66.1729 - val_loss: 28920.2949 - val_mae: 84.7606
# Epoch 45/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 25828.0059 - mae: 71.1452 - val_loss: 29707.3047 - val_mae: 90.3281
# Epoch 46/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 25622.3340 - mae: 73.7770 - val_loss: 28736.2051 - val_mae: 79.6060
# Epoch 47/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 19277.6289 - mae: 64.7131 - val_loss: 29215.5117 - val_mae: 86.2003
# Epoch 48/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 33069.8906 - mae: 73.1233 - val_loss: 29985.6738 - val_mae: 71.4742
# Epoch 49/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 33656.4219 - mae: 73.2463 - val_loss: 28728.2383 - val_mae: 82.5324
# Epoch 50/50
# 104/104 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 18328.2852 - mae: 64.6438 - val_loss: 29439.8633 - val_mae: 84.5469
# 56/56 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 0.312991201877594

# %% [markdown]
# # Dla wybranego modelu - random forest

# %%
predictions = model1.predict(test_inputs)

# Mean absolute error dla wybranego modelu (błąd jaki przyjmujemy)
print(round(mean_absolute_error(test_days, predictions), 2))
# Out:
# 63.27

# %%
predictions
# Out:
# array([27.98314549, 20.71671532, 59.68364675, ..., 32.12435608,
#        56.45215258, 32.12435608])

# %%
# Wartości różnic pomiędzy faktycznymi
differences = predictions - test_days
differences.name = 'różnica'
differences
# Out:
# 2040     26.983145
# 1075     17.716715
# 213      22.683647
# 5230     31.124356
# 4462     22.124356
#            ...
# 4772    153.021329
# 1041     26.552090
# 4964     15.124356
# 2957     37.452153
# 186       4.124356
# Name: różnica, Length: 1777, dtype: float64

# %%
import matplotlib.pyplot as plt

# Tworzenie histogramu dla różnic
differences.hist(bins=50, edgecolor='k')
plt.xlim(-200, 200)
plt.show()

# %% [markdown]
# Predykcje są większe niż wartości rzeczywiste

# %% [markdown]
# # Pytania

# %%
gatunek = input("Jakiego gatunku jest zwierzę? Wpisz 'pies' lub 'kot'. ")
płeć = input("Jakiej płci jest zwierzę? Wpisz 'samiec' lub samica'. ")
rasa = input("Jakiej rasy jest zwierzę? Jeżeli żadnej, wpisz 'mieszaniec'. ")
wiek = int(input("Ile miesięcy ma zwierzę? "))
waga = int(input("Ile kilogramów waży zwierzę? Podaj liczbę całkowitą. "))
przyjazny = int(input("Czy zwierzę jest przyjazne? Wpisz 0 jeśli nie lub 1 jeśli tak. "))
agresywny	= int(input("Czy zwierzę jest agresywne? Wpisz 0 jeśli nie lub 1 jeśli tak. "))
chory	= int(input("Czy zwierzę jest chore? Wpisz 0 jeśli nie lub 1 jeśli tak. "))
bojący_się	= int(input("Czy zwierzę jest strachliwe? Wpisz 0 jeśli nie lub 1 jeśli tak. "))
aktywny = int(input("Czy zwierzę jest aktywne? Wpisz 0 jeśli nie lub 1 jeśli tak. "))

# %%
data = [
    {'gatunek': gatunek, 'rasa': rasa, 'płeć': płeć, 'wiek_miesiące': wiek, 'waga_kg': waga,
     'przyjazny': przyjazny,	'agresywny': agresywny,	'chory': chory,	'bojący się': bojący_się,	'aktywny': aktywny}
]

df_do_przewidywania = pd.DataFrame(data)

kolumny_docelowe = df_do_modelu.columns

df_dopasowany = pd.get_dummies(df_do_przewidywania, columns = ["rasa", "gatunek", "płeć"])
df_dopasowany = df_do_przewidywania.reindex(columns = kolumny_docelowe, fill_value = 0)
df_dopasowany = df_dopasowany.astype(bool)
df_dopasowany = df_dopasowany.drop(columns = ["czas_pobytu_dni"], errors = 'ignore')

liczba_dni = model1.predict(df_dopasowany)[0]

print("Szacowany czas pobytu wprowadzonego zwierzęcia w schronisku wynosi", int(liczba_dni), "dni.")
